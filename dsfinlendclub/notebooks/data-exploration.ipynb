# %% [raw]
# %load_ext kedro.ipython

# %%
# %reload_ext kedro.ipython
# Out:
# [03/24/25 11:17:33] INFO     Using                                                                  ]8;id=456853;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/framework/project/__init__.py\__init__.py]8;;\:]8;id=15810;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/framework/project/__init__.py#249\249]8;;\
#                              '/Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site
#                              -packages/kedro/framework/project/rich_logging.yml' as logging
#                              configuration.
#                     INFO     Registered line magic '%reload_kedro'                                   ]8;id=600871;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=120450;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#58\58]8;;\
#                     INFO     Registered line magic '%load_node'                                      ]8;id=986107;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=608010;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#60\60]8;;\
#                     INFO     Resolved project path as:                                              ]8;id=527128;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=620692;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#175\175]8;;\
#                              /Users/macbook/Documents/GitHub/DSfinProject/dsfinlendclub.
#                              To set a different path, run '%reload_kedro <project_root>'
# [03/24/25 11:17:34] INFO     Kedro is sending anonymous usage data with the sole purpose of improving ]8;id=215933;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro_telemetry/plugin.py\plugin.py]8;;\:]8;id=518909;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro_telemetry/plugin.py#233\233]8;;\
#                              the product. No personal data or IP addresses are stored on our side. If
#                              you want to opt out, set the `KEDRO_DISABLE_TELEMETRY` or `DO_NOT_TRACK`
#                              environment variables, or create a `.telemetry` file in the current
#                              working directory with the contents `consent: false`. Read more at
#                              https://docs.kedro.org/en/stable/configuration/telemetry.html
#                     INFO     Kedro project DSfinLendClub                                            ]8;id=817638;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=208029;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#141\141]8;;\
#                     INFO     Defined global variable 'context', 'session', 'catalog' and            ]8;id=143261;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py\__init__.py]8;;\:]8;id=823650;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/ipython/__init__.py#142\142]8;;\
#                              'pipelines'

# %%
df = catalog.load("lendingclub")
df.head()
# Out:
# [03/24/25 11:18:17] INFO     Loading data from lendingclub (CSVDataset)...                      ]8;id=482475;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=277056;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py#539\539]8;;\
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/pandas/io/parsers │
# │ /c_parser_wrapper.py:239 in read                                                                 │
# │                                                                                                  │
# │   236 │   │   │   │   data = _concatenate_chunks(chunks)                                         │
# │   237 │   │   │                                                                                  │
# │   238 │   │   │   else:                                                                          │
# │ ❱ 239 │   │   │   │   data = self._reader.read(nrows)                                            │
# │   240 │   │   except StopIteration:                                                              │
# │   241 │   │   │   if self._first_chunk:                                                          │
# │   242 │   │   │   │   self._first_chunk = False                                                  │
# │                                                                                                  │
# │ in pandas._libs.parsers.TextReader.read:796                                                      │
# │                                                                                                  │
# │ in pandas._libs.parsers.TextReader._read_rows:891                                                │
# │                                                                                                  │
# │ in pandas._libs.parsers.TextReader._convert_column_data:1049                                     │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/pandas/core/dtype │
# │ s/common.py:1335 in is_extension_array_dtype                                                     │
# │                                                                                                  │
# │   1332 │   )                                                                                     │
# │   1333                                                                                           │
# │   1334                                                                                           │
# │ ❱ 1335 def is_extension_array_dtype(arr_or_dtype) -> bool:                                       │
# │   1336 │   """                                                                                   │
# │   1337 │   Check if an object is a pandas extension array type.                                  │
# │   1338                                                                                           │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 df = catalog.load("lendingclub")                                                             │
# │   2 df.head(5)                                                                                   │
# │   3                                                                                              │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/io/data_cat │
# │ alog.py:546 in load                                                                              │
# │                                                                                                  │
# │   543 │   │   │   extra={"markup": True},                                                        │
# │   544 │   │   )                                                                                  │
# │   545 │   │                                                                                      │
# │ ❱ 546 │   │   result = dataset.load()                                                            │
# │   547 │   │                                                                                      │
# │   548 │   │   return result                                                                      │
# │   549                                                                                            │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/io/core.py: │
# │ 223 in load                                                                                      │
# │                                                                                                  │
# │   220 │   │   │   self._logger.debug("Loading %s", str(self))                                    │
# │   221 │   │   │                                                                                  │
# │   222 │   │   │   try:                                                                           │
# │ ❱ 223 │   │   │   │   return load_func(self)                                                     │
# │   224 │   │   │   except DatasetError:                                                           │
# │   225 │   │   │   │   raise                                                                      │
# │   226 │   │   │   except Exception as exc:                                                       │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro_datasets/pa │
# │ ndas/csv_dataset.py:163 in _load                                                                 │
# │                                                                                                  │
# │   160 │   │   │   # (<urlopen error file not on local host>),                                    │
# │   161 │   │   │   # so we don't join that back to the filepath;                                  │
# │   162 │   │   │   # storage_options also don't work with local paths                             │
# │ ❱ 163 │   │   │   return pd.read_csv(load_path, **self._load_args)                               │
# │   164 │   │                                                                                      │
# │   165 │   │   load_path = f"{self._protocol}{PROTOCOL_DELIMITER}{load_path}"                     │
# │   166 │   │   return pd.read_csv(                                                                │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/pandas/io/parsers │
# │ /readers.py:912 in read_csv                                                                      │
# │                                                                                                  │
# │    909 │   )                                                                                     │
# │    910 │   kwds.update(kwds_defaults)                                                            │
# │    911 │                                                                                         │
# │ ❱  912 │   return _read(filepath_or_buffer, kwds)                                                │
# │    913                                                                                           │
# │    914                                                                                           │
# │    915 # iterator=True -> TextFileReader                                                         │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/pandas/io/parsers │
# │ /readers.py:583 in _read                                                                         │
# │                                                                                                  │
# │    580 │   │   return parser                                                                     │
# │    581 │                                                                                         │
# │    582 │   with parser:                                                                          │
# │ ❱  583 │   │   return parser.read(nrows)                                                         │
# │    584                                                                                           │
# │    585                                                                                           │
# │    586 # iterator=True -> TextFileReader                                                         │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/pandas/io/parsers │
# │ /readers.py:1704 in read                                                                         │
# │                                                                                                  │
# │   1701 │   │   │   │   │   index,                                                                │
# │   1702 │   │   │   │   │   columns,                                                              │
# │   1703 │   │   │   │   │   col_dict,                                                             │
# │ ❱ 1704 │   │   │   │   ) = self._engine.read(  # type: ignore[attr-defined]                      │
# │   1705 │   │   │   │   │   nrows                                                                 │
# │   1706 │   │   │   │   )                                                                         │
# │   1707 │   │   │   except Exception:                                                             │
# │                                                                                                  │
# │ /Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/pandas/io/parsers │
# │ /c_parser_wrapper.py:239 in read                                                                 │
# │                                                                                                  │
# │   236 │   │   │   │   data = _concatenate_chunks(chunks)                                         │
# │   237 │   │   │                                                                                  │
# │   238 │   │   │   else:                                                                          │
# │ ❱ 239 │   │   │   │   data = self._reader.read(nrows)                                            │
# │   240 │   │   except StopIteration:                                                              │
# │   241 │   │   │   if self._first_chunk:                                                          │
# │   242 │   │   │   │   self._first_chunk = False                                                  │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# KeyboardInterrupt

# %%
df_sample = catalog.load("lsample")
df_sample.dtypes
# Out:
# [03/21/25 15:24:23] INFO     Loading data from lsample (CSVDataset)...                          ]8;id=934496;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=607213;file:///Users/macbook/Documents/GitHub/DSfinProject/.venv/lib/python3.8/site-packages/kedro/io/data_catalog.py#539\539]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Unnamed: 0.1                                    int64
# Unnamed: 0                                      int64
# id                                              int64
# loan_amnt                                     float64
# funded_amnt                                   float64
#                                                ...
# hardship_loan_status                           object
# orig_projected_additional_accrued_interest    float64
# hardship_payoff_balance_amount                float64
# hardship_last_payment_amount                  float64
# debt_settlement_flag                           object
# Length: 143, dtype: object

# %%
df_sample.head(5)
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#    Unnamed: 0.1  Unnamed: 0         id  loan_amnt  funded_amnt  \
# 0       1746494       25450  167338079     4000.0       4000.0
# 1       2370717       81861   71016917    24000.0      24000.0
# 2       2264870      397109   39589826     5000.0       5000.0
# 3        595422       15492  134798709    24000.0      24000.0
# 4        562657       90591  127097355    14000.0      14000.0
#
#    funded_amnt_inv        term int_rate  installment grade  ...  \
# 0           4000.0   36 months   13.08%       134.93     B  ...
# 1          24000.0   60 months    9.16%       500.07     B  ...
# 2           5000.0   36 months   10.49%       162.49     B  ...
# 3          24000.0   60 months   11.05%       522.42     B  ...
# 4          14000.0   60 months   13.59%       322.79     C  ...
#
#   hardship_start_date hardship_end_date payment_plan_start_date  \
# 0                 NaN               NaN                     NaN
# 1                 NaN               NaN                     NaN
# 2                 NaN               NaN                     NaN
# 3                 NaN               NaN                     NaN
# 4                 NaN               NaN                     NaN
#
#   hardship_length  hardship_dpd hardship_loan_status  \
# 0             NaN           NaN                  NaN
# 1             NaN           NaN                  NaN
# 2             NaN           NaN                  NaN
# 3             NaN           NaN                  NaN
# 4             NaN           NaN                  NaN
#
#   orig_projected_additional_accrued_interest hardship_payoff_balance_amount  \
# 0                                        NaN                            NaN
# 1                                        NaN                            NaN
# 2                                        NaN                            NaN
# 3                                        NaN                            NaN
# 4                                        NaN                            NaN
#
#   hardship_last_payment_amount debt_settlement_flag
# 0                          NaN                    N
# 1                          NaN                    N
# 2                          NaN                    N
# 3                          NaN                    N
# 4                          NaN                    N
#
# [5 rows x 143 columns]

# %%
df.drop(columns=['desc', 'member_id', 'url', 'zip_code'], inplace=True)
df.fillna(df.median(), inplace=True)  # Numerical columns
df.fillna('Unknown', inplace=True)  # Categorical columns

# %%
df['term'] = df['term'].str.extract('(\d+)').astype(int)
df['income_to_loan_ratio'] = df['annual_inc'] / df['loan_amnt']
df['loan_utilization'] = df['revol_bal'] / df['total_rev_hi_lim']
df['credit_history_length'] = pd.to_datetime(df['issue_d']) - pd.to_datetime(df['earliest_cr_line'])
df['credit_history_length'] = df['credit_history_length'].dt.days / 365  # Convert to years
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# grade
# B    29216
# C    27400
# A    22457
# D    14212
# E     4872
# F     1423
# G      420
# Name: count, dtype: int64
